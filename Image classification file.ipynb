# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # 2. Remove dodgy images

# %%
import cv2
import imghdr
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23628\4232469594.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))

# %% [markdown]
# # 3. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 305 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 4. Scale Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.48235294, 0.42745098, 0.4862745 ],
#           [0.48137254, 0.4343137 , 0.48921567],
#           [0.48120403, 0.4341452 , 0.48904717],
#           ...,
#           [0.38883272, 0.35746017, 0.4162837 ],
#           [0.38861826, 0.3572457 , 0.41606924],
#           [0.3882353 , 0.35686275, 0.41568628]],
#
#          [[0.48235294, 0.42745098, 0.4862745 ],
#           [0.48137254, 0.4343137 , 0.48921567],
#           [0.485769  , 0.43871018, 0.49361214],
#           ...,
#           [0.39557293, 0.36420035, 0.4230239 ],
#           [0.3882353 , 0.35686275, 0.41568628],
#           [0.38431373, 0.3529412 , 0.4117647 ]],
#
#          [[0.4862745 , 0.43137255, 0.49019608],
#           [0.48235294, 0.43529412, 0.49019608],
#           [0.4862745 , 0.4392157 , 0.49411765],
#           ...,
#           [0.3923407 , 0.36096814, 0.41979167],
#           [0.39229473, 0.3609222 , 0.4197457 ],
#           [0.38449755, 0.353125  , 0.41194853]],
#
#          ...,
#
# ...

# %% [markdown]
# # 5. Split Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 7

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # 6. Build Deep Learning Model

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TextVectorization, Embedding, LSTM, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# d:\AIML\SEABORN\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 16)     │         4,624 │
# ...

# %% [markdown]
# # 7. Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 952ms/step - accuracy: 0.4955 - loss: 0.9885 - val_accuracy: 0.5469 - val_loss: 0.6515
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.5130 - loss: 0.6680 - val_accuracy: 0.8281 - val_loss: 0.6368
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 573ms/step - accuracy: 0.7715 - loss: 0.5995 - val_accuracy: 0.7656 - val_loss: 0.5775
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 613ms/step - accuracy: 0.8294 - loss: 0.4768 - val_accuracy: 0.9062 - val_loss: 0.3688
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 634ms/step - accuracy: 0.8258 - loss: 0.3991 - val_accuracy: 0.7500 - val_loss: 0.4843
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 742ms/step - accuracy: 0.7909 - loss: 0.4265 - val_accuracy: 0.9531 - val_loss: 0.2813
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 668ms/step - accuracy: 0.8886 - loss: 0.3299 - val_accuracy: 0.9688 - val_loss: 0.2006
# Epoch 8/20
# ...

# %%
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

# %%
print(f"Final Training Accuracy: {train_accuracy[-1] * 100:.2f}%")
print(f"Final Validation Accuracy: {val_accuracy[-1] * 100:.2f}%")
# Out:
# Final Training Accuracy: 99.11%
# Final Validation Accuracy: 100.00%

# %% [markdown]
# # 8. Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# # 10. Test

# %%
import cv2
import pyttsx3
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
img = cv2.imread('data/happy/Screen-Shot-2012-10-23-at-12.57.22-PM.png')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
engine = pyttsx3.init()

# %%
img = cv2.imread('D:\\AIML\\SEABORN\\Scripts\\practice\\f1\\frame_with_faces_0.png')
resize = tf.image.resize(img, (256, 256))

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step

# %%
if yhat > 0.5:
    text_output = 'Predicted class is Sad'
    
else:
    text_output = 'Predicted class is Happy'

# %%
print(text_output)
# Out:
# Predicted class is Happy

# %%
import cv2
import os

# Example: Let's assume you already have an image stored in the variable `image`
# Replace this with your actual image object if it's loaded from a file or created programmatically
image = cv2.imread("path_to_your_image/image.png")

# Specify the folder where you want to save the image
save_folder = "saved_images"

# Create the folder if it doesn't exist
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# Define the full path for the image file including the image name
img_name = os.path.join(save_folder, "saved_image.png")

# Save the image to the specified folder
cv2.imwrite(img_name, image)

print(f"Image saved as {img_name}")

# %%
engine.say(text_output)
engine.runAndWait()

# %%
plt.imshow(resize.numpy().astype(int))
plt.title(text_output)
plt.show()

# %% [markdown]
# # 11. Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','imageclassifier.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
new_model = load_model("imageclassifier.h5",compile=False)

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# array([[1.4976261e-07]], dtype=float32)
